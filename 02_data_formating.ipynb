# %%
Data_Path = r'/home/youssef/Documents/Data Science/stack over flow/data/processed/1_preprocessed_df.pkl'
Export_Path = r'/home/youssef/Documents/Data Science/stack over flow/data/processed/2_preprocessed_df.pkl'

# %%
# Remove ";"
def remove_semicolon(df):
    for col in df.select_dtypes(include=['object', 'string']).columns:
        if df[col].astype(str).str.contains(';').any():
            df[col] = df[col].str.replace(';', ',', regex = False)
    return df

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pd.options.display.max_rows = 100    
pd.set_option('display.max_columns', None)       
pd.options.display.max_seq_items = 100
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Formating

# %%
cleaned_df = pd.read_pickle(Data_Path)
df = cleaned_df.copy()

# %%
df.head()
# Out:
#   YearsCodePro                DevType  \
# 2           27   Developer Experience
# 3            0  Developer, full-stack
# 4            0  Developer, full-stack
# 5            0                Student
# 6            7    Academic researcher
#
#                                              Country  \
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Canada
# 4                                             Norway
# 5                           United States of America
# 6                           United States of America
#
#                               LanguageHaveWorkedWith  \
# 2                                                 C#
# 3  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4            C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 5  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                  R
#
#             DatabaseHaveWorkedWith                   PlatformHaveWorkedWith  \
# 2       Firebase Realtime Database                             Google Cloud
# 3  MongoDB;MySQL;PostgreSQL;SQLite  Amazon Web Services (AWS);Fly.io;Heroku
# 4                PostgreSQL;SQLite                                        0
# 5                  Cloud Firestore                               Cloudflare
# 6                                0                                        0
#
#                    WebframeHaveWorkedWith   EmbeddedHaveWorkedWith  \
# 2                            ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React;WordPress              Rasberry Pi
# 4                                       0  CMake;Cargo;Rasberry Pi
# 5                                 Node.js              Rasberry Pi
# 6                                       0                        0
#
#                             MiscTechHaveWorkedWith  \
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                                0
# 5                                                0
# 6                                                0
#
#         ToolsTechHaveWorkedWith       NEWCollabToolsHaveWorkedWith  \
# 2                       MSBuild                      Visual Studio
# 3                Docker;npm;Pip                                  0
# 4                  APT;Make;npm                                Vim
# 5  Docker;Homebrew;npm;Pip;pnpm  Nano;Vim;Visual Studio Code;Xcode
# 6                             0                            RStudio
#
#          OpSysPersonal use OpSysProfessional use  \
# 2                  Windows               Windows
# 3                        0                     0
# 4  Other (please specify):                     0
# 5         iOS;MacOS;Ubuntu                     0
# 6                    MacOS                 MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 2                                                  0
# 3                                                  0
# 4  GitHub Discussions;Markdown File;Obsidian;Stac...
# 5                                      Markdown File
# 6                                                  0
#
#                   OfficeStackSyncHaveWorkedWith  \
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom
# 3                                             0
# 4                              Discord;Whatsapp
# 5                                       Discord
# 6                      Microsoft Teams;Whatsapp
#
#              AISearchDevHaveWorkedWith  WorkExp
# 2                                    0      0.0
# 3                                    0      0.0
# 4                                    0      0.0
# 5  ChatGPT;GitHub Copilot;OpenAI Codex      0.0
# 6                                    0      0.0

# %%
df.dtypes
# Out:
# YearsCodePro                       object
# DevType                            object
# Country                            object
# LanguageHaveWorkedWith             object
# DatabaseHaveWorkedWith             object
# PlatformHaveWorkedWith             object
# WebframeHaveWorkedWith             object
# EmbeddedHaveWorkedWith             object
# MiscTechHaveWorkedWith             object
# ToolsTechHaveWorkedWith            object
# NEWCollabToolsHaveWorkedWith       object
# OpSysPersonal use                  object
# OpSysProfessional use              object
# OfficeStackAsyncHaveWorkedWith     object
# OfficeStackSyncHaveWorkedWith      object
# AISearchDevHaveWorkedWith          object
# WorkExp                           float64
# dtype: object

# %%
df.drop(columns = 'Country', inplace=True)

# %%
df['YearsCodePro'].unique()
# Out:
# array(['27', 0, '7', '11', '25', '12', '3', '10', 'Less than 1 year',
#        '18', '37', '15', '20', '17', '6', '2', '16', '8', '14', '45', '4',
#        '1', '24', '29', '5', '30', '26', '9', '33', '13', '35', '23',
#        '22', '31', '19', '21', '28', '34', '32', '40', '50', '39', '44',
#        '42', '41', '36', '38', 'More than 50 years', '43', '47', '48',
#        '46', '49'], dtype=object)

# %%
df['YearsCodePro'] = df['YearsCodePro'].replace({'Less than 1 year':'0', 'More than 50 years':'51'})

# %%
df['YearsCodePro'].unique()
# Out:
# array(['27', 0, '7', '11', '25', '12', '3', '10', '0', '18', '37', '15',
#        '20', '17', '6', '2', '16', '8', '14', '45', '4', '1', '24', '29',
#        '5', '30', '26', '9', '33', '13', '35', '23', '22', '31', '19',
#        '21', '28', '34', '32', '40', '50', '39', '44', '42', '41', '36',
#        '38', '51', '43', '47', '48', '46', '49'], dtype=object)

# %%
df['YearsCodePro'] = df['YearsCodePro'].astype('int64')

# %%
df['DevType'].unique()
# Out:
# array(['Developer Experience', 'Developer, full-stack', 'Student',
#        'Academic researcher', 'Project manager', 'Developer Advocate',
#        'Developer, back-end', 'Other (please specify):',
#        'Developer, front-end', 'Database administrator',
#        'Developer, desktop or enterprise applications',
#        'Cloud infrastructure engineer',
#        'Data scientist or machine learning specialist',
#        'Research & Development role',
#        'Developer, embedded applications or devices',
#        'System administrator', 'DevOps specialist', 'Engineering manager',
#        'Designer', 'Security professional',
#        'Senior Executive (C-Suite, VP, etc.)', 'Developer, mobile',
#        'Developer, game or graphics', 'Data or business analyst',
#        'Educator', 'Developer, QA or test', 'Product manager',
#        'Developer, AI', 'Scientist', 'Engineer, site reliability',
#        'Blockchain', 'Marketing or sales professional',
#        'Hardware Engineer', 'Data engineer'], dtype=object)

# %%
filtered_rows = df[df['DevType'] == 'Other (please specify):']
filtered_rows.head()
# Out:
#     YearsCodePro                  DevType  \
# 13             0  Other (please specify):
# 20             0  Other (please specify):
# 31             7  Other (please specify):
# 55            24  Other (please specify):
# 60             0  Other (please specify):
#
#                                LanguageHaveWorkedWith  \
# 13                                         PHP;Python
# 20  Bash/Shell (all shells);HTML/CSS;PHP;Python;SQ...
# 31  Bash/Shell (all shells);Go;HTML/CSS;Python;Sca...
# 55                                    C;Go;Python;SQL
# 60  Assembly;C++;Go;HTML/CSS;JavaScript;Julia;Lisp...
#
#                      DatabaseHaveWorkedWith  \
# 13                            MariaDB;MySQL
# 20                                    MySQL
# 31         Databricks SQL;DuckDB;PostgreSQL
# 55                            DuckDB;SQLite
# 60  Cloud Firestore;MySQL;PostgreSQL;SQLite
#
#                   PlatformHaveWorkedWith WebframeHaveWorkedWith  \
# 13                                     0            CodeIgniter
# 20                                     0                 Django
# 31  Amazon Web Services (AWS);Databricks                      0
# 55                                     0                      0
# 60                   Cloudflare;Firebase      Htmx;jQuery;React
#
#                             EmbeddedHaveWorkedWith     MiscTechHaveWorkedWith  \
# 13                                           CMake                          0
# 20                             Arduino;Rasberry Pi        NumPy;Opencv;Pandas
# 31                                               0  Apache Spark;NumPy;Pandas
# 55                                               0               NumPy;Pandas
# 60  Arduino;CMake;Cargo;GNU GCC;LLVM's Clang;QMake           Opencv;OpenGL;Qt
#
#                      ToolsTechHaveWorkedWith  \
# 13                                   Ant;APT
# 20                              Homebrew;Pip
# 31  Docker;Homebrew;Kubernetes;Pip;Terraform
# 55                         Homebrew;Make;Nix
# 60             APT;Docker;Ninja;npm;Pip;Vite
#
#                          NEWCollabToolsHaveWorkedWith  \
# 13                   Visual Studio;Visual Studio Code
# 20  Eclipse;Jupyter Notebook/JupyterLab;PyCharm;Vi...
# 31                 DataGrip;IntelliJ IDEA;PyCharm;Vim
# 55  Jupyter Notebook/JupyterLab;PyCharm;Visual Stu...
# 60                               CLion;Qt Creator;Vim
#
#                                     OpSysPersonal use  \
# 13  MacOS;Ubuntu;Windows;Windows Subsystem for Lin...
# 20                           iOS;MacOS;Ubuntu;Windows
# 31          Windows;Windows Subsystem for Linux (WSL)
# 55     MacOS;Ubuntu;Windows Subsystem for Linux (WSL)
# 60                                             Ubuntu
#
#                                OpSysProfessional use  \
# 13  Ubuntu;Windows;Windows Subsystem for Linux (WSL)
# 20                                    Ubuntu;Windows
# 31                                             MacOS
# 55                                           Windows
# 60                                            Ubuntu
#
#    OfficeStackAsyncHaveWorkedWith  \
# 13                              0
# 20                           Miro
# 31    Jira;Miro;Monday.com;Notion
# 55                              0
# 60                           Jira
#
#                         OfficeStackSyncHaveWorkedWith  \
# 13                                            Discord
# 20  Jitsi;Mattermost;Microsoft Teams;Signal;Skype;...
# 31                                         Slack;Zoom
# 55                                                  0
# 60  Discord;Google Meet;Jitsi;Microsoft Teams;Slac...
#
#                AISearchDevHaveWorkedWith  WorkExp
# 13                               ChatGPT      0.0
# 20                               ChatGPT     10.0
# 31                        GitHub Copilot      7.0
# 55                                     0      0.0
# 60  ChatGPT;GitHub Copilot;Google Gemini      0.0

# %%
df.drop(filtered_rows.index, inplace=True)

# %%
df['DevType'] = df['DevType'].astype('string')

# %%
df['DevType'] = df['DevType'].str.lower()

# %%
df['LanguageHaveWorkedWith'].unique().tolist()
# Out:
# ['C#',
#  'C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'C++;HTML/CSS;JavaScript;Lua;Python;Rust',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;Rust;Swift;TypeScript',
#  'R',
#  'HTML/CSS;JavaScript;TypeScript',
#  'Lua',
#  'JavaScript;Python;Ruby',
#  'C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;PowerShell;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C#;JavaScript;PowerShell;VBA',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'Rust;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;Python;SQL',
#  'PowerShell;SQL',
#  'C#;HTML/CSS;Java;PHP;SQL',
#  'Bash/Shell (all shells);C#;F#;JavaScript;PowerShell;SQL',
#  'HTML/CSS;JavaScript;PHP;Python;SQL',
#  'Clojure;Java;JavaScript;SQL',
#  'C#;HTML/CSS;Java;JavaScript;Python;SQL;VBA;Visual Basic (.Net)',
#  'C#;HTML/CSS;JavaScript;Python;Scala;SQL',
#  'Bash/Shell (all shells);Lua;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL',
#  'C#;HTML/CSS;JavaScript;SQL',
#  'Go;HTML/CSS;Java;JavaScript;Perl;Python;TypeScript',
#  'Bash/Shell (all shells);JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell (all shells);Python',
#  'C++;HTML/CSS;Java;JavaScript;MATLAB;Perl;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;PowerShell;Python;SQL;VBA',
#  'Bash/Shell (all shells);C#;Java;OCaml;SQL',
#  'Python',
#  'HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript',
#  'C;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Ruby;SQL',
#  'Bash/Shell (all shells);C++;Python',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'Assembly;C#;C++;HTML/CSS;JavaScript;MATLAB;Python;SQL;VBA',
#  'C#;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C;C++',
#  'Crystal;Julia;R;Ruby',
#  'Delphi;Fortran;SQL',
#  'Java;JavaScript;SQL',
#  'Assembly;C#;Java;JavaScript;Python;Rust',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript;VBA',
#  'C;HTML/CSS;Java;JavaScript;PowerShell;SQL;TypeScript',
#  'C++;HTML/CSS;JavaScript;Kotlin;Lua;PowerShell;Python;SQL;TypeScript',
#  'C#;JavaScript;Lua',
#  'C;C++;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C#;Java;PowerShell;Python;SQL',
#  'C#;JavaScript;SQL;TypeScript',
#  'Assembly;C;HTML/CSS;JavaScript',
#  'PowerShell;Ruby',
#  'Java',
#  'Assembly;C;C++;Dart;Kotlin;PHP;SQL',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Dart;Haskell;Java;Python;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Kotlin;Perl;Python;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;SQL;Visual Basic (.Net)',
#  'C#;PowerShell;SQL',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Python;R;SQL;TypeScript',
#  'C++;Python;R',
#  'Ada;Assembly;Bash/Shell (all shells);C;C++;Clojure;Crystal;Dart;Elixir;Erlang;Fortran;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;Lisp;Lua;OCaml;Perl;PowerShell;Python;R;Rust;Scala;SQL;TypeScript;Zig',
#  'HTML/CSS;JavaScript',
#  'Groovy;HTML/CSS;Java;JavaScript;Python',
#  'Bash/Shell (all shells);C++;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;SQL',
#  'C#;JavaScript;TypeScript',
#  'C#;PowerShell;Rust',
#  'Go;HTML/CSS;JavaScript;Python;TypeScript',
#  'C;Python',
#  'Bash/Shell (all shells);C;C++;Go;JavaScript;Python',
#  'C#;C++;HTML/CSS;JavaScript;Kotlin;Lua;PowerShell;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'HTML/CSS;Python;Rust',
#  'C#;HTML/CSS;JavaScript;SQL;VBA;Visual Basic (.Net)',
#  'C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;PHP;Python;Rust;SQL;TypeScript',
#  'C;C++;Groovy;HTML/CSS;Java;JavaScript;PHP;Python;SQL',
#  'GDScript;JavaScript;PHP',
#  'C#;HTML/CSS;JavaScript;PHP;PowerShell',
#  'C#;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);C#;JavaScript',
#  'Bash/Shell (all shells);C;C++;Java;Python',
#  'C#;JavaScript;PowerShell;SQL',
#  'C;C#;C++;HTML/CSS;Java;JavaScript;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;SQL',
#  'Go;PHP;Python;SQL',
#  'C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;HTML/CSS;Python',
#  'Assembly;Bash/Shell (all shells);C;C++;F#;Haskell;HTML/CSS;Java;JavaScript;PowerShell;Python;Scala;SQL;TypeScript',
#  'C#;HTML/CSS;VBA',
#  'HTML/CSS;Java;JavaScript;Prolog;Scala;TypeScript',
#  'C;C#;HTML/CSS;Java;Python;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;PowerShell;Python',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Kotlin;TypeScript',
#  'C;C#;C++;Elixir;Erlang;Go;HTML/CSS;Java;JavaScript;PHP;Python;R;Ruby;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'JavaScript;TypeScript',
#  'Bash/Shell (all shells);C;C++;Kotlin;PowerShell;Python;Rust',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;TypeScript',
#  'C#;Go;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;SQL',
#  'Java;JavaScript;Kotlin;Lua;MicroPython;Python;Rust;Scala;TypeScript',
#  'Go',
#  'HTML/CSS;Java;JavaScript;Python;TypeScript',
#  'HTML/CSS;Kotlin;Objective-C;Python;Ruby;Swift;TypeScript',
#  'Go;Python',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Dart;Go;HTML/CSS;Java;Kotlin;Python;Rust;SQL',
#  'C#;C++;HTML/CSS;JavaScript;PowerShell;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;SQL',
#  'C++',
#  'HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;Rust;SQL',
#  'C#;PowerShell;Python',
#  'C;C#;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;TypeScript',
#  'Assembly;C;C#;C++;HTML/CSS;JavaScript;Lua;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);Dart;JavaScript;Python;SQL',
#  'C;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;HTML/CSS;Java;JavaScript;Python;Rust;TypeScript',
#  'C#;HTML/CSS;JavaScript;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Dart;Python;Swift',
#  'HTML/CSS;SQL;VBA',
#  'Go;Java;JavaScript;Kotlin;PHP;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  0,
#  'C#;HTML/CSS;Python;SQL',
#  'Python;TypeScript',
#  'C;C++;JavaScript;Lua;Python;Rust;SQL;TypeScript',
#  'HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'HTML/CSS;JavaScript;SQL;TypeScript',
#  'C;C#;C++;HTML/CSS;JavaScript;TypeScript',
#  'Go;Rust;Zig',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Lua;Python;TypeScript',
#  'Java;TypeScript',
#  'C;C#;C++;Haskell;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'HTML/CSS;JavaScript;Kotlin;Lua;MATLAB;PowerShell;Python;SQL;TypeScript',
#  'Assembly;C;C++;HTML/CSS;JavaScript;Objective-C;PHP;Python;SQL',
#  'C;C++;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;Go;PowerShell;Python;SQL',
#  'HTML/CSS;JavaScript;PHP;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;Dart;Haskell;HTML/CSS;Java;JavaScript;Kotlin;Prolog;Python;SQL;TypeScript',
#  'C#;Go;Groovy;HTML/CSS;Java;JavaScript;SQL',
#  'Assembly;C;C++;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;Prolog;Python;R;SQL;TypeScript',
#  'Bash/Shell (all shells);C;Clojure;Dart;Lua',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Kotlin;Python;Rust;SQL;TypeScript',
#  'JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript;Visual Basic (.Net)',
#  'Go;HTML/CSS;Java;JavaScript;PowerShell;SQL',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Kotlin;Swift',
#  'C;C++;Python',
#  'Dart;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Perl;PHP;PowerShell;Python;R;SQL',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Python;Rust',
#  'Bash/Shell (all shells);Dart;HTML/CSS;Java;JavaScript;SQL',
#  'HTML/CSS;Java;JavaScript;SQL',
#  'C++;Java;JavaScript;Python;TypeScript;VBA',
#  'HTML/CSS;Java;JavaScript;PHP',
#  'Assembly;Bash/Shell (all shells);C;Haskell;HTML/CSS;JavaScript;OCaml;Python;Rust;Scala;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Lua;PowerShell;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'R;SQL;VBA',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;PowerShell;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'JavaScript;PHP;Python;Rust',
#  'Bash/Shell (all shells);C;C#;Go;HTML/CSS;JavaScript;Python;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);JavaScript;Python;Rust',
#  'JavaScript;PHP;SQL',
#  'C;C++;PowerShell;Python;SQL',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript',
#  'C#;Go;JavaScript;PowerShell;TypeScript',
#  'C#;C++;F#;JavaScript;PowerShell;SQL;TypeScript',
#  'C#;F#',
#  'C;C++;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'C;C++;Java;Kotlin;MATLAB;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);Java;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;Rust;TypeScript',
#  'C#;HTML/CSS',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Lua;Python;Rust',
#  'HTML/CSS;JavaScript;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;PowerShell;Python;SQL',
#  'Python;R',
#  'C;C++;Groovy;Java;Julia;MATLAB;Python;SQL',
#  'Dart;JavaScript',
#  'Bash/Shell (all shells);C;C++;Dart;Go;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'Delphi',
#  'C++;Java;Python',
#  'C;C++;Dart;HTML/CSS;Java;PHP;Python;SQL',
#  'HTML/CSS;JavaScript;PHP',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'C;C++;Python;Rust',
#  'C#;Ruby',
#  'Assembly;Bash/Shell (all shells);C;Java;MicroPython;PHP;Rust',
#  'Bash/Shell (all shells);C++;HTML/CSS;JavaScript;PowerShell;Python;Ruby;SQL;TypeScript',
#  'C#;Java;JavaScript;Python;SQL',
#  'C++;Go;Java;JavaScript;Kotlin;Objective-C;Python;SQL;Swift',
#  'Bash/Shell (all shells);C;C++;MATLAB;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);Go;Java;JavaScript;Python;TypeScript',
#  'Assembly;C;C#;HTML/CSS;Java;JavaScript;MATLAB;PowerShell;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;PHP;R;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;C++;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'C#;C++;Go;Lua;Python',
#  'JavaScript;Python;SQL;TypeScript',
#  'C;C#;Dart;HTML/CSS;JavaScript;PHP;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);Elixir;Go;Groovy;HTML/CSS;Java;JavaScript;Ruby;SQL;TypeScript',
#  'C;C#;Python',
#  'C#;Go;JavaScript;PHP;SQL',
#  'HTML/CSS;JavaScript;Lisp;Python;SQL',
#  'C#;C++;HTML/CSS;JavaScript;Python;VBA;Visual Basic (.Net)',
#  'Go;Rust;SQL;TypeScript',
#  'Groovy;Java;JavaScript;MATLAB;Python',
#  'JavaScript;SQL;TypeScript',
#  'C#;C++;Java;Lua;PowerShell;Python;SQL',
#  'C#;JavaScript;PowerShell;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;Dart;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;Python;Scala',
#  'C;C#;C++;GDScript;HTML/CSS;Java;JavaScript;Kotlin;Python;Rust;SQL',
#  'HTML/CSS;Java;JavaScript;Kotlin;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;SQL',
#  'HTML/CSS;Java;JavaScript',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Lua;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;Lua;PHP;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Go;JavaScript',
#  'Groovy;Java;Kotlin;PowerShell',
#  'Go;Rust',
#  'Bash/Shell (all shells);C;C++;Cobol;Delphi;Go;Java;JavaScript;Lua;Perl;PHP;Python;SQL',
#  'Bash/Shell (all shells);C#;Java;JavaScript;Python;Swift',
#  'C;C++;Objective-C;PHP;Python;Ruby;Swift;TypeScript',
#  'Go;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell (all shells)',
#  'JavaScript',
#  'C;HTML/CSS;Java;JavaScript;MATLAB;Python',
#  'Dart;JavaScript;Python',
#  'Java;Python',
#  'C;Go;Ruby',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;JavaScript;Lua;Objective-C;PHP;Ruby;SQL;Zig',
#  'HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;Groovy;Java',
#  'Assembly;Bash/Shell (all shells);C;C++',
#  'Bash/Shell (all shells);Java;JavaScript',
#  'Bash/Shell (all shells);Objective-C;Perl;Swift',
#  'Bash/Shell (all shells);C;C++;Java;Objective-C;Python',
#  'Go;JavaScript;Lua;PHP;SQL',
#  'HTML/CSS;Java;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C++;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;SQL;TypeScript',
#  'Go;JavaScript;Python;TypeScript',
#  'HTML/CSS;Java;TypeScript',
#  'Java;JavaScript;Rust;Scala;TypeScript',
#  'Bash/Shell (all shells);Dart;Go;HTML/CSS;JavaScript;Lua;Nim;Python;Rust;TypeScript',
#  'Go;HTML/CSS;JavaScript;TypeScript',
#  'Elixir;HTML/CSS;JavaScript;PHP',
#  'Apex;Java;JavaScript;SQL',
#  'Bash/Shell (all shells);C#;Java;Python;SQL',
#  'C++;HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Rust;SQL;TypeScript',
#  'C++;Java;MATLAB;Python',
#  'C#;Delphi;Go;SQL',
#  'Bash/Shell (all shells);C;C++;Go;Lua;Python;SQL',
#  'HTML/CSS;JavaScript;Python;TypeScript',
#  'HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Lua;Perl;PowerShell;Python;Ruby;Rust;SQL;TypeScript',
#  'Dart',
#  'SQL;VBA',
#  'C#;Java;Python;Scala;SQL',
#  'Java;Lua;Python;Rust;SQL',
#  'Java;SQL',
#  'C;C++;Dart;Go;Haskell;Lua;Zig',
#  'Bash/Shell (all shells);Go;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;SQL',
#  'JavaScript;Solidity;TypeScript',
#  'C;C#;C++;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;Java;JavaScript;Kotlin;Objective-C;Python;Swift',
#  'Bash/Shell (all shells);Groovy;Java;JavaScript;Python;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Lua;Python',
#  'C;C#;C++;Dart;HTML/CSS;JavaScript;Lua;MATLAB;PowerShell;Python;TypeScript',
#  'C;C++;HTML/CSS;Java;JavaScript;Perl;PHP;Python;R;Ruby;SQL',
#  'C++;HTML/CSS;JavaScript;PHP',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;PHP;PowerShell;Python;Ruby;SQL;Swift;TypeScript;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C++',
#  'C++;Java;MicroPython;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C#;JavaScript;Scala',
#  'HTML/CSS;JavaScript;SQL',
#  'C;C#;C++;Dart;Fortran;Go;HTML/CSS;Java;JavaScript;Kotlin;Perl;PHP;PowerShell;Python;Ruby;Rust;SQL;Swift;Visual Basic (.Net)',
#  'HTML/CSS;Java;JavaScript;TypeScript',
#  'Objective-C;Python;Swift',
#  'C#;Kotlin;Swift;TypeScript',
#  'C;C++;Fortran;MATLAB;Python;SQL',
#  'C;C++;HTML/CSS;Java;JavaScript;Python',
#  'HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'C#;JavaScript;Ruby',
#  'C++;Delphi;SQL',
#  'JavaScript;Julia;Python;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Ruby',
#  'Bash/Shell (all shells);HTML/CSS;Perl;SQL;TypeScript',
#  'Groovy;Java;Kotlin;SQL',
#  'Assembly;Swift;VBA',
#  'C#;Go;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Go;Java;Python;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;VBA',
#  'HTML/CSS;JavaScript;Lua;TypeScript',
#  'HTML/CSS;JavaScript;Ruby;TypeScript',
#  'Bash/Shell (all shells);Groovy;PowerShell;SQL',
#  'C#;HTML/CSS;Java;JavaScript;MicroPython;Python;TypeScript',
#  'C;C#;C++;HTML/CSS;Java;SQL;VBA',
#  'Bash/Shell (all shells);C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;PHP;Prolog;Python;SQL',
#  'C;Java;JavaScript;PowerShell;Python',
#  'Assembly;C#;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;SQL',
#  'Delphi;SQL',
#  'Bash/Shell (all shells);C;Python',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP',
#  'Bash/Shell (all shells);C#;Cobol;HTML/CSS;JavaScript;Perl;Python;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C++;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Python;Rust;Scala;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Python',
#  'HTML/CSS;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java;JavaScript;MATLAB;Perl;Prolog;Python;R;TypeScript',
#  'Ada;Assembly;Bash/Shell (all shells);C;C#;C++;Dart;Delphi;HTML/CSS;Java;JavaScript;MATLAB;Perl;PHP;PowerShell;Python;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C;GDScript;Go;HTML/CSS;JavaScript;Lua;Python;Rust;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Kotlin',
#  'Bash/Shell (all shells);C;C++;Groovy;HTML/CSS;Java;JavaScript',
#  'Java;JavaScript;Python',
#  'Bash/Shell (all shells);Elixir;JavaScript;TypeScript',
#  'C++;Rust',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'Go;Java;Prolog;Python',
#  'Dart;Java;Kotlin;Swift',
#  'Bash/Shell (all shells);C#;Dart;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);Go;Python;Rust',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;C++;Go;HTML/CSS;JavaScript;PowerShell;SQL',
#  'C#;Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript',
#  'C++;Elixir;Python;TypeScript',
#  'C;Rust',
#  'Go;HTML/CSS',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'C++;HTML/CSS;JavaScript;Lisp;PowerShell;Python',
#  'HTML/CSS;JavaScript;Python',
#  'C;Clojure;Java;Julia;Kotlin;OCaml;Python;R;Rust;Scala;SQL',
#  'C#;HTML/CSS;Java;JavaScript;Python',
#  'HTML/CSS;Java;JavaScript;Kotlin;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python',
#  'Go;Groovy;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Apex;C#;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C#;Dart;Go;HTML/CSS;JavaScript;Kotlin;PHP;PowerShell;SQL;Swift;TypeScript',
#  'C;GDScript;HTML/CSS;JavaScript;PHP;Python',
#  'C#;C++;Delphi;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;SQL',
#  'Bash/Shell (all shells);JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go',
#  'Java;SQL;TypeScript',
#  'C;HTML/CSS;JavaScript;Python',
#  'C#;HTML/CSS;JavaScript;PowerShell;TypeScript',
#  'Ruby;Swift',
#  'C#;C++;F#;Rust',
#  'C;JavaScript;MicroPython;Python;SQL',
#  'C#;C++;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C;C#;C++',
#  'Go;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'GDScript;MATLAB;Python',
#  'C;C++;Perl;SQL',
#  'C;C#;C++;Python',
#  'C#;HTML/CSS;Java;JavaScript;Kotlin;Lua;PHP;SQL',
#  'Bash/Shell (all shells);C;C++;Haskell;HTML/CSS;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);Java;JavaScript;TypeScript',
#  'HTML/CSS;Python',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Perl;Python;SQL',
#  'Java;Kotlin',
#  'Assembly;Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java;JavaScript;Julia;Lua;Python',
#  'Python;SQL',
#  'C#;GDScript;HTML/CSS;JavaScript;Lua;PowerShell',
#  'Bash/Shell (all shells);C#;Java;JavaScript;Lua;Objective-C;PHP',
#  'C#;JavaScript;MATLAB',
#  'Bash/Shell (all shells);Objective-C;Rust;Swift',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Kotlin;Perl;PHP;Python;Ruby;SQL;TypeScript;VBA',
#  'HTML/CSS;JavaScript;Perl;PHP;SQL',
#  'C#;HTML/CSS;SQL;TypeScript',
#  'Ada;C++;JavaScript;MATLAB;Python;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Clojure;Rust',
#  'C++;HTML/CSS;Java;JavaScript;Python;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript',
#  'Ada;Apex;Assembly;Bash/Shell (all shells);C++;Dart;HTML/CSS;Java;JavaScript;Objective-C',
#  'MATLAB;Python;R',
#  'Bash/Shell (all shells);C;C#;C++;Python;Rust;SQL',
#  'C#;SQL;Swift',
#  'Bash/Shell (all shells);C;JavaScript;Perl;PHP;Python;SQL',
#  'Go;JavaScript;PHP;PowerShell;Python;Ruby;SQL',
#  'Delphi;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);C#;C++;PowerShell',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;F#;Go;HTML/CSS;JavaScript;PHP;PowerShell;Python;Ruby;Rust;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby;SQL;Swift;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'C#;HTML/CSS;PowerShell;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'C;C++;Objective-C;PHP',
#  'C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'C#;JavaScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;SQL',
#  'Bash/Shell (all shells);C++;HTML/CSS;JavaScript;PHP;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;Go;HTML/CSS;JavaScript;Python;TypeScript',
#  'Bash/Shell (all shells);C;JavaScript;Lua;Perl;PHP;Python;Ruby;SQL',
#  'C;C#;C++;HTML/CSS;JavaScript;Python;SQL;Zig',
#  'C#;C++;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;Clojure;GDScript;HTML/CSS;Java;JavaScript;Kotlin;Lua;Python;Rust;TypeScript',
#  'Go;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);Fortran;Python',
#  'Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Python;TypeScript',
#  'Bash/Shell (all shells);C#;JavaScript;PowerShell;SQL;Visual Basic (.Net)',
#  'C#;C++;Lua;PowerShell;SQL',
#  'C;C++;JavaScript;Python;Zephyr',
#  'C++;Lua;MicroPython;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Rust;SQL;TypeScript',
#  'Go;Java',
#  'C#;C++;SQL',
#  'C;Haskell;HTML/CSS;Java;JavaScript;Prolog;Python;R;SQL;TypeScript',
#  'C;Go;HTML/CSS;JavaScript;Python;Scala;SQL',
#  'C#;HTML/CSS;PowerShell;Python;SQL;VBA;Visual Basic (.Net)',
#  'Java;JavaScript',
#  'Bash/Shell (all shells);Go;Java;JavaScript;Lisp;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'HTML/CSS;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;PowerShell;Python;SQL',
#  'C;Dart;Delphi;SQL',
#  'Bash/Shell (all shells);C#;Go;Java;JavaScript;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Dart;HTML/CSS;JavaScript;Rust',
#  'Bash/Shell (all shells);C;HTML/CSS;Java;JavaScript;Kotlin;Perl;Python;SQL',
#  'C#;F#;HTML/CSS;JavaScript;Python;TypeScript',
#  'Bash/Shell (all shells);PHP;R;SQL',
#  'R;SQL',
#  'Bash/Shell (all shells);C;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Lua;PHP;Python;SQL;Swift;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;MicroPython;PowerShell;Python',
#  'Bash/Shell (all shells);C#;Clojure;Elixir;Erlang;Go;Haskell;HTML/CSS;JavaScript;Lisp;OCaml;Prolog;Rust;SQL;TypeScript',
#  'C#;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go;HTML/CSS;JavaScript;Python;TypeScript',
#  'C#;JavaScript;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);Python;SQL',
#  'Bash/Shell (all shells);C#;Groovy;HTML/CSS;Java;JavaScript;Python;R;SQL',
#  'Dart;HTML/CSS;JavaScript;Kotlin;PHP;Python;SQL;TypeScript',
#  'C++;Java;PHP',
#  'C#;JavaScript;PHP;TypeScript',
#  'Bash/Shell (all shells);SQL',
#  'Go;Python;Ruby;Rust;SQL',
#  'Assembly;Bash/Shell (all shells);C#;GDScript;HTML/CSS;JavaScript;Lua;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;Dart;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;PowerShell;Python;Scala;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;PHP;Python',
#  'C;C#;C++;HTML/CSS;Java;JavaScript;MicroPython;PHP;Python;SQL',
#  'Assembly;C;C++',
#  'Bash/Shell (all shells);C;C++;MATLAB;Perl;Python',
#  'C#;PowerShell',
#  'C;C#;C++;Dart;GDScript;HTML/CSS;Java;JavaScript;Kotlin;PHP;SQL;Swift;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C;C++;Lisp;Python',
#  'C#;HTML/CSS;JavaScript;Python',
#  'Bash/Shell (all shells);Go;Python',
#  'Dart;Haskell;Java;Kotlin;Python;R',
#  'C++;HTML/CSS;SQL',
#  'Dart;HTML/CSS;JavaScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Ruby;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;Java;JavaScript;Python;Rust',
#  'Bash/Shell (all shells);C++;Julia;Python;Rust',
#  'C++;HTML/CSS;JavaScript;Python',
#  'Bash/Shell (all shells);C;C++;Go;Java;Python;Rust;SQL',
#  'HTML/CSS;Java;JavaScript;Python',
#  'C;C#;C++;JavaScript;Objective-C;PowerShell;Python;Scala;Swift;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;Dart;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;PowerShell;TypeScript',
#  'F#;SQL',
#  'C;HTML/CSS;Java;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);C#;Dart;Delphi;Fortran;HTML/CSS;PowerShell;SQL;VBA',
#  'Bash/Shell (all shells);Java;JavaScript;PHP;SQL;TypeScript',
#  'C;Erlang;Fortran;Python;SQL',
#  'Python;Rust',
#  'C#;Java;JavaScript;Python;SQL;TypeScript',
#  'Apex;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;PHP;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Lua;Nim;PHP;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);JavaScript;Python',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Lua;PowerShell;Python;Rust',
#  'C#;HTML/CSS;SQL',
#  'Groovy;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#  'Kotlin',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'JavaScript;Python;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL;TypeScript',
#  'C;C#;C++;Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL',
#  'JavaScript;PHP;Python;SQL;TypeScript',
#  'Groovy;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;SQL;TypeScript;VBA',
#  'C#;C++;HTML/CSS;SQL',
#  'Dart;Go;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;PHP;SQL;Swift;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C#;JavaScript;Rust;SQL',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Rust;TypeScript',
#  'C++;Fortran;Python',
#  'Assembly;Cobol;JavaScript;PowerShell;Python;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;PowerShell;SQL;TypeScript',
#  'MicroPython;Python',
#  'Java;JavaScript;TypeScript',
#  'Dart;Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;Go;Java;JavaScript;PHP;PowerShell;Ruby;Rust;SQL;TypeScript',
#  'C#;Dart;HTML/CSS;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Java',
#  'Bash/Shell (all shells);C;Go;JavaScript;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;C++;Groovy;HTML/CSS;Java;JavaScript;MATLAB;PHP;PowerShell;Python;R;Ruby;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Python;Swift',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;SQL;VBA',
#  'Apex;C;Cobol;Ruby',
#  'Bash/Shell (all shells);C++;Dart;Go;JavaScript;Lua;Python;Ruby;Rust;TypeScript',
#  'HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);Ruby;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Lua;SQL;TypeScript',
#  'C#;HTML/CSS;PowerShell;Python;Visual Basic (.Net)',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;Ruby',
#  'C++;HTML/CSS;Java;JavaScript;MATLAB;PHP;SQL;Swift;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C;C#;Python',
#  'Assembly;Bash/Shell (all shells);C++;Python;Rust;TypeScript',
#  'Groovy;HTML/CSS;Lua;Python;SQL',
#  'C;HTML/CSS;JavaScript;Kotlin;Python;Swift;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;JavaScript;Lua;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C++;Dart;HTML/CSS;PHP;Python;SQL',
#  'C;C++;Go;JavaScript;TypeScript',
#  'C#;JavaScript;SQL',
#  'C++;Go;Python;Rust',
#  'Bash/Shell (all shells);Dart;Go;HTML/CSS;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'Java;Kotlin;PHP',
#  'C;OCaml',
#  'C#;Groovy;HTML/CSS;PowerShell',
#  'C#;C++;JavaScript;Julia;Python;Rust;TypeScript',
#  'C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;Delphi;Lua;Objective-C;Python;VBA;Zig',
#  'Java;JavaScript;Kotlin;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;TypeScript',
#  'Bash/Shell (all shells);C#;GDScript;Go;Haskell;HTML/CSS;Java;JavaScript;Julia;Nim;PHP;Python;R;Rust;SQL',
#  'PHP;PowerShell;SQL',
#  'Dart;Zig',
#  'Apex;C#;Go;Rust;SQL',
#  'C#;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;R;SQL',
#  'C#;PowerShell;Swift',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#  'HTML/CSS;JavaScript;Python;SQL;VBA',
#  'C#;Go;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);Java;Kotlin;Python;SQL',
#  'Bash/Shell (all shells);C;C++;Go;HTML/CSS;JavaScript;Perl;Python;SQL',
#  'C;C#;C++;Java;Python;Rust',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;JavaScript;Lua;SQL;TypeScript',
#  'Assembly;C;C++;HTML/CSS;JavaScript;Python;R;TypeScript',
#  'Bash/Shell (all shells);C#;Go;Groovy;HTML/CSS;JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java;JavaScript;Perl;PHP;PowerShell;Python;SQL;VBA',
#  'Bash/Shell (all shells);C#;C++;F#;Go;Python;Rust',
#  'Assembly;Bash/Shell (all shells);C;C++;R',
#  'HTML/CSS;Java;JavaScript;Python;Rust;SQL;TypeScript',
#  'C#;SQL',
#  'C#;Go;HTML/CSS;Java;JavaScript;PowerShell;Python;TypeScript',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;Java;JavaScript;Python;R;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;GDScript;Go;HTML/CSS;Java;JavaScript;Python',
#  'Bash/Shell (all shells);C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;TypeScript',
#  'C;C++;Java',
#  'C#;Java',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Solidity;SQL',
#  'Bash/Shell (all shells);GDScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;Dart;GDScript;Go;Groovy;HTML/CSS;Java;JavaScript;Lua;Objective-C;Rust;SQL;Swift;TypeScript;Zig',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;PHP;Python;SQL;Swift',
#  'Assembly;C;C#;C++;Java;JavaScript;Perl;PHP;Python;R;SQL;VBA;Visual Basic (.Net)',
#  'C#;C++;JavaScript;PowerShell;Python;TypeScript',
#  'C#;GDScript;JavaScript;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Assembly;C++;Go;Java;Objective-C;PHP;Python;Swift',
#  'Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;Perl;PHP;PowerShell;Python;Ruby;SQL',
#  'PHP',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;GDScript;HTML/CSS;JavaScript;PHP;PowerShell;SQL',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Python;Swift;TypeScript',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;PowerShell;TypeScript',
#  'Go;HTML/CSS;JavaScript;Python',
#  'Java;Kotlin;PHP;Swift',
#  'C#;HTML/CSS;Python',
#  'C#;C++;HTML/CSS;Java;JavaScript;Lua;MicroPython;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Perl;PHP;PowerShell',
#  'Bash/Shell (all shells);Delphi;HTML/CSS;JavaScript;PHP;PowerShell;SQL',
#  'Bash/Shell (all shells);Go;Java;PowerShell;SQL',
#  'Assembly;Bash/Shell (all shells);C;C++;Cobol;Go;Haskell;HTML/CSS;Java;JavaScript;MicroPython;Python;Rust;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;MicroPython;PowerShell;Python;SQL;TypeScript;VBA;Visual Basic (.Net)',
#  'Haskell;TypeScript',
#  'C#;Fortran;Python;SQL',
#  'Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;PHP;TypeScript',
#  'C;JavaScript;Lua;Python;SQL',
#  'C#;Go;HTML/CSS;JavaScript;Lua;PHP;Python;TypeScript',
#  'HTML/CSS;Python;TypeScript',
#  'Bash/Shell (all shells);C;C++',
#  'C#;SQL;VBA',
#  'C#;HTML/CSS;JavaScript;Kotlin;Objective-C;Swift;TypeScript',
#  'HTML/CSS;Java;JavaScript;Ruby;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python;Ruby;SQL',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;Lua;PowerShell;Python;Rust;SQL',
#  'Cobol;Java;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C;Go;Groovy;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#  'JavaScript;Python',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Objective-C;Perl;PHP;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;Scala;SQL',
#  'Swift',
#  'Bash/Shell (all shells);C++;Java;Kotlin;Rust',
#  'JavaScript;Python;Ruby;SQL;TypeScript',
#  'Assembly;C;Python',
#  'Bash/Shell (all shells);C;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;Rust;TypeScript',
#  'Bash/Shell (all shells);JavaScript;Lisp;Python;Rust;SQL',
#  'C;C++;HTML/CSS;Java;JavaScript;PHP;Prolog;Python;R;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;PowerShell;SQL',
#  'C;HTML/CSS',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Lua;Perl;PHP;Python;SQL;TypeScript',
#  'JavaScript;Rust;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;MATLAB;Perl;PowerShell;Python;R;SQL;VBA',
#  'Bash/Shell (all shells);C#;Groovy;HTML/CSS;JavaScript;Kotlin;Python;R;SQL;Swift;TypeScript',
#  'Bash/Shell (all shells);Go;Lua',
#  'C;C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript;Visual Basic (.Net)',
#  'C;Go;JavaScript;Ruby',
#  'C#;HTML/CSS;JavaScript;PowerShell;Python;SQL',
#  'C;MATLAB;MicroPython;Python',
#  'Bash/Shell (all shells);HTML/CSS;PHP;Python;SQL',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Kotlin;Python;Scala;TypeScript',
#  'C#;C++;Python',
#  'C;C++;Java;JavaScript;PHP;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;PowerShell;Python;SQL',
#  'C#;C++;PowerShell;SQL',
#  'Bash/Shell (all shells);Go;JavaScript;Python;SQL;TypeScript',
#  'C#;Rust',
#  'C#;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'HTML/CSS;JavaScript;PowerShell',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Lua;TypeScript',
#  'Bash/Shell (all shells);C++;Go;Java;JavaScript;Lua;Python;Rust',
#  'C#;GDScript;HTML/CSS;JavaScript;SQL;TypeScript',
#  'HTML/CSS;JavaScript;PowerShell;Python;SQL;Swift;TypeScript',
#  'C;JavaScript;PHP',
#  'Bash/Shell (all shells);C;C++;Java;PHP;PowerShell;Python;TypeScript',
#  'Assembly;C;C++;Haskell;Python;Zig',
#  'Bash/Shell (all shells);C;Fortran;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'Bash/Shell (all shells);C;C++;Groovy;Java;Kotlin;Python;SQL',
#  'TypeScript',
#  'Ruby',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Kotlin;SQL;TypeScript',
#  'C;C#;Dart;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'HTML/CSS;TypeScript',
#  'Go;HTML/CSS;Java;JavaScript;Python;SQL',
#  'C;C++;Java;JavaScript;Rust;TypeScript',
#  'Bash/Shell (all shells);C;C#;JavaScript;Ruby',
#  'Assembly;Bash/Shell (all shells);C;C++;JavaScript;R;SQL',
#  'HTML/CSS;JavaScript;PHP;Swift;TypeScript',
#  'Assembly;C#;Go;PowerShell;Ruby;Rust',
#  'C++;Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript',
#  'C++;Python',
#  'PowerShell',
#  'C;C#;HTML/CSS;Java;Python;Rust',
#  'Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;Ruby;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL',
#  'JavaScript;PowerShell;Python;SQL;Swift',
#  'Bash/Shell (all shells);C;Go;Java;PowerShell;Python',
#  'Bash/Shell (all shells);C;Haskell;HTML/CSS;Lua',
#  'C#;Python;SQL',
#  'Bash/Shell (all shells);GDScript;Java;Scala',
#  'Groovy;JavaScript;Python;R;SQL',
#  'Go;Java;Kotlin',
#  'C#;C++;Fortran;Python;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Objective-C;PHP;PowerShell;Python;R;Ruby;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Kotlin;SQL;TypeScript',
#  'Java;JavaScript;PHP;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL;Swift;TypeScript',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ruby;SQL',
#  'C;Python;Rust',
#  'C;Java;JavaScript;Python;SQL;TypeScript',
#  'C;Objective-C;Rust;Swift',
#  'Go;HTML/CSS;Ruby;SQL',
#  'C;C++;Dart;Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'C#;Delphi;HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  'C#;C++;HTML/CSS;JavaScript;Kotlin;PowerShell;Python;Rust;Scala;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'C#;HTML/CSS;TypeScript',
#  'C#;Delphi;JavaScript;PHP',
#  'C#;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'Dart;Java',
#  'C++;HTML/CSS;JavaScript;Lua;PHP;Rust;SQL;TypeScript',
#  'Rust',
#  'Bash/Shell (all shells);Julia;Lua;Python;R;SQL',
#  'HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;TypeScript',
#  'Bash/Shell (all shells);C;C#;Java;Perl;PHP;SQL',
#  'C#;HTML/CSS;JavaScript;TypeScript',
#  'C#;C++;HTML/CSS;JavaScript;Kotlin',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Lua;PowerShell;Python;Rust;SQL;TypeScript',
#  'Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;SQL;TypeScript',
#  'Apex;C#;Ruby',
#  'C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;Rust;SQL',
#  'Bash/Shell (all shells);Java;Kotlin',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);SQL;Swift',
#  'C#;C++;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'C;C++;JavaScript',
#  'C;C++;JavaScript;Python;SQL;Swift',
#  'Bash/Shell (all shells);C;Go;HTML/CSS;Objective-C;Python;SQL;VBA',
#  'Bash/Shell (all shells);C++;HTML/CSS;Java;Python;Rust;SQL',
#  'Bash/Shell (all shells);C;Haskell;HTML/CSS;Java;Lua;PowerShell;Python',
#  'C#;GDScript;JavaScript;Kotlin;Python;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go;Java;JavaScript;Python;Ruby;Rust',
#  'Bash/Shell (all shells);C;C#;C++;Fortran;Java;MATLAB;Python;R',
#  'Delphi;HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  'C#;Go;Java;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Lisp;Lua;Perl;PHP;Python;SQL',
#  'Python;R;SQL',
#  'C++;Go',
#  'C++;MATLAB;Python',
#  'HTML/CSS;Java;JavaScript;Perl;PHP;R;SQL;TypeScript',
#  'Bash/Shell (all shells);Go;Lua;Rust',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Perl;Python;Ruby;VBA',
#  'C#;HTML/CSS;JavaScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C;Lisp;MATLAB;Python;SQL',
#  'Assembly;Bash/Shell (all shells);C#;Go;JavaScript;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);C#;Dart;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Assembly;C;C++;Python',
#  'C;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;C++;Groovy;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL',
#  'Haskell;Java;JavaScript;Julia;Perl;Prolog;Python',
#  'Julia;Python;R;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;MATLAB;Perl;PHP;PowerShell;Python;SQL;TypeScript',
#  'C#;Dart;HTML/CSS;JavaScript;Python;SQL',
#  'Assembly;C',
#  'C;C++;HTML/CSS;Java;JavaScript;PowerShell;Python;TypeScript',
#  'Bash/Shell (all shells);Go;Groovy;Java;JavaScript;Python;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Kotlin;PHP;Solidity;SQL;TypeScript',
#  'C;C#;C++;Go;HTML/CSS;Java;JavaScript;Python',
#  'HTML/CSS;Java;SQL;TypeScript',
#  'Go;HTML/CSS;JavaScript;Ruby;SQL',
#  'Go;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);Erlang;Haskell;HTML/CSS;JavaScript;Lua;OCaml;PHP;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;Python;Rust;SQL',
#  'C#;HTML/CSS;Java;Kotlin;PHP;TypeScript',
#  'C;Java;Kotlin',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);Go;Java;JavaScript;Kotlin;Python;Rust;SQL;TypeScript',
#  'C#;F#;Lua;SQL',
#  'JavaScript;Python;R',
#  'C++;HTML/CSS;JavaScript;PowerShell;Python;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;Lisp;OCaml;Python;Rust',
#  'Bash/Shell (all shells);Java;JavaScript;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Python;TypeScript',
#  'Bash/Shell (all shells);Go;Java;JavaScript;Kotlin;Ruby;Rust;SQL;TypeScript',
#  'Ada;Assembly;C;C#;C++;Dart;Delphi;Go;Java;Prolog;Python;Rust;SQL;Visual Basic (.Net)',
#  'JavaScript;PHP;TypeScript',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScript;PowerShell;Python;SQL',
#  'C#;Python',
#  'HTML/CSS;Lua;MATLAB;Python;R;SQL',
#  'C++;HTML/CSS;JavaScript;Lua;Python;Rust;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C;C++;Go;Java;JavaScript;PowerShell;Rust;TypeScript',
#  'C;C#;C++;Go;HTML/CSS;JavaScript;Kotlin;Lua;Perl;PHP;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;SQL',
#  'C;C#;C++;Dart;HTML/CSS;Java;JavaScript;Kotlin',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Lua;PHP;SQL',
#  'Dart;Java;Python;SQL',
#  'SQL;TypeScript',
#  'C#;HTML/CSS;Python;TypeScript',
#  'Kotlin;Ruby;Swift',
#  'Assembly;C#;C++;Java;PowerShell;SQL',
#  'C;C++;Delphi;Fortran;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;VBA',
#  'Bash/Shell (all shells);C;C++;Java;PowerShell;Python;SQL',
#  'Ada;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;Perl;PHP;Python;SQL',
#  'Bash/Shell (all shells);C;Go;HTML/CSS;Java;Python',
#  'Bash/Shell (all shells);C++;Fortran;Python',
#  'Dart;Python',
#  'HTML/CSS;Java;JavaScript;MATLAB;PowerShell;SQL;VBA',
#  'Bash/Shell (all shells);JavaScript;Kotlin;Python',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Python;Rust;SQL',
#  'Bash/Shell (all shells);HTML/CSS;PHP;SQL;TypeScript',
#  'C#;C++;Go;Rust;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript',
#  'C#;HTML/CSS;JavaScript;PHP;Python;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;Clojure;Go;HTML/CSS;Java;JavaScript;MATLAB;MicroPython;PowerShell;Python;Rust;TypeScript',
#  'C++;HTML/CSS;Java;JavaScript;Kotlin;SQL;TypeScript',
#  'Bash/Shell (all shells);C;Java;Perl;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;Dart;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Perl;PHP;Python;Rust;SQL;Swift;Visual Basic (.Net)',
#  'C#;HTML/CSS;Java;JavaScript;PHP;PowerShell;SQL;VBA;Visual Basic (.Net)',
#  'C#;HTML/CSS;JavaScript;PHP',
#  'HTML/CSS;JavaScript;PowerShell;Ruby;SQL;TypeScript',
#  'MATLAB;Python;R;SQL',
#  'C#;Delphi;HTML/CSS;SQL;VBA',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Go;Haskell;Java;Kotlin;PHP;Python;Rust;SQL;Swift',
#  'Bash/Shell (all shells);C#;SQL;TypeScript',
#  'C;C#;C++;Dart;HTML/CSS;JavaScript;Kotlin;PowerShell;Rust;SQL;Swift;TypeScript',
#  'Go;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'C++;Java;JavaScript;Kotlin;Python;TypeScript',
#  'C#;PowerShell;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PHP;Python;TypeScript',
#  'Bash/Shell (all shells);Python;R;SQL',
#  'GDScript;Go;HTML/CSS;JavaScript;Lua;MicroPython;PHP;PowerShell;Python;SQL',
#  'C;C++;Java;Lua',
#  'HTML/CSS;JavaScript;PowerShell;TypeScript',
#  'Bash/Shell (all shells);C;C++;Java;JavaScript;Perl;PHP;PowerShell;Python;SQL;VBA',
#  'Assembly;Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PHP;Python;R;SQL;VBA;Visual Basic (.Net)',
#  'C#;Elixir;Erlang;Go;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;Haskell;PowerShell;Python;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Lua;PowerShell;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C++;Go;Python',
#  'JavaScript;PHP;Python',
#  'HTML/CSS;Java;JavaScript;MATLAB;PHP;SQL',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;MATLAB;PHP;SQL',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;PowerShell;Prolog;Python;R;SQL;TypeScript',
#  'Bash/Shell (all shells);Rust;SQL;Swift',
#  'Java;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;MATLAB;Python',
#  'Bash/Shell (all shells);C;HTML/CSS;JavaScript;Python',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScript;Python;Rust;SQL',
#  'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PowerShell;Python',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;SQL',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL',
#  'C;C#;C++;Dart;Go;JavaScript;Python;Rust',
#  'Bash/Shell (all shells);C;Clojure;Go;HTML/CSS;JavaScript;Python;Rust;TypeScript',
#  'C;C++;JavaScript;Objective-C;Python;SQL',
#  'Clojure;Go;Java',
#  'C;Python;Visual Basic (.Net)',
#  'C#;C++;Lua;Python',
#  'Bash/Shell (all shells);C#;C++;HTML/CSS;JavaScript;PHP;TypeScript',
#  'C#;SQL;TypeScript;Visual Basic (.Net)',
#  'C++;JavaScript;Python;TypeScript',
#  'C#;Dart;SQL',
#  'C;C#;C++;GDScript;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;HTML/CSS',
#  'C#;C++',
#  'Bash/Shell (all shells);HTML/CSS;Python;TypeScript',
#  'C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Python;SQL;Swift;TypeScript;Visual Basic (.Net)',
#  'Go;Python;Rust;TypeScript',
#  'HTML/CSS;JavaScript;Kotlin;PHP;Ruby;SQL',
#  'C;C#;C++;Clojure;HTML/CSS;Java;JavaScript;Lua;PHP;Python;Rust;SQL',
#  'C;C#;C++;Dart;HTML/CSS;JavaScript;PHP;Python;SQL',
#  'Go;JavaScript;PHP;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Dart;GDScript;Kotlin;TypeScript',
#  'Bash/Shell (all shells);C++;Dart;Python;SQL',
#  'HTML/CSS;JavaScript;SQL;Swift',
#  'Go;Python;SQL',
#  'C;C++;Go;Lua;PowerShell;Python;Ruby;SQL',
#  'Go;Python;R;SQL',
#  'Bash/Shell (all shells);Go;HTML/CSS;JavaScript;Python;SQL;Swift;TypeScript',
#  'C;C++;HTML/CSS;JavaScript;MATLAB;PHP;Python;R;SQL;Visual Basic (.Net)',
#  'Assembly;C;C++;Java;Kotlin;MATLAB;Python;SQL',
#  'C#;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);HTML/CSS;JavaScript;Perl;PHP;PowerShell;Python;SQL;VBA',
#  'Bash/Shell (all shells);C;HTML/CSS;Java;JavaScript;PHP;Python;SQL',
#  'JavaScript;Solidity',
#  'C#;C++;HTML/CSS;PowerShell;Python;SQL',
#  'HTML/CSS;Java;JavaScript;Objective-C;Python;SQL;Swift',
#  'Bash/Shell (all shells);Perl;PHP;SQL',
#  'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;PHP;PowerShell;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Kotlin;Lua;PHP;Python',
#  'C;C#;C++;Java;OCaml;Python',
#  'Elixir;Erlang;Go;Kotlin;PHP;SQL;Zig',
#  'Bash/Shell (all shells);Go;Java;Python;SQL',
#  'C#;Python;TypeScript',
#  'Bash/Shell (all shells);PHP;SQL',
#  'C;C#;C++;Dart;Go;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;PowerShell;Python;Rust;SQL;Swift;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);C;C#;C++;Delphi;PowerShell;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL;TypeScript',
#  'C;C#;C++;Rust',
#  'C#;HTML/CSS;JavaScript;Python;SQL;TypeScript',
#  'Go;SQL',
#  'Bash/Shell (all shells);C;C++;MATLAB;PowerShell;Python',
#  'Bash/Shell (all shells);PHP;Python;SQL',
#  'Elixir;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);Java;Python;SQL',
#  'Ada;Assembly;C;C#;C++;Python;Zephyr',
#  'Assembly;Bash/Shell (all shells);C;HTML/CSS;Java;JavaScript;Kotlin;Python;Rust;TypeScript',
#  'Assembly;C#;SQL',
#  'C#;HTML/CSS;Java;JavaScript;PowerShell;Python',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;JavaScript;PowerShell;SQL;TypeScript',
#  'GDScript;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;HTML/CSS;JavaScript',
#  'C;HTML/CSS;Python',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Go;Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;Swift;TypeScript',
#  'C;C#;C++;HTML/CSS;Java;JavaScript;Python;R;SQL',
#  'C++;Clojure;Python',
#  'Bash/Shell (all shells);HTML/CSS;Julia;MATLAB;Python',
#  'Bash/Shell (all shells);Delphi;JavaScript;PHP;SQL',
#  'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;PowerShell;SQL',
#  'HTML/CSS;Java;JavaScript;Kotlin;Lua;MATLAB;Python;Swift;TypeScript;Visual Basic (.Net)',
#  'C#;VBA;Visual Basic (.Net)',
#  'C#;HTML/CSS;JavaScript;Kotlin;Swift;TypeScript',
#  'Bash/Shell (all shells);C#;C++;Java;Kotlin;Objective-C;Python;SQL;Swift;TypeScript',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;JavaScript;Lua;Python;Ruby',
#  'Assembly;Bash/Shell (all shells);C;C++;Julia;Python',
#  'Ada',
#  'Bash/Shell (all shells);Clojure;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;Scala;SQL;Swift;TypeScript;Visual Basic (.Net)',
#  'HTML/CSS;JavaScript;Python;R;SQL;VBA',
#  'Assembly;Bash/Shell (all shells);C;C++;Perl;Python',
#  'HTML/CSS;JavaScript;MATLAB;Python;Rust;SQL;TypeScript',
#  'C#;Delphi;HTML/CSS;JavaScript;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;OCaml;Python;SQL',
#  'C#;HTML/CSS;Java;JavaScript',
#  'HTML/CSS;JavaScript;PHP;R;SQL;TypeScript',
#  'C#;HTML/CSS;JavaScript;PowerShell;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby;Rust;Scala;SQL',
#  'Java;JavaScript;SQL;TypeScript',
#  'HTML/CSS;Java;JavaScript;Kotlin;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;HTML/CSS;JavaScript;Python;SQL',
#  'C#;Groovy;HTML/CSS;Java;JavaScript;OCaml;PowerShell;SQL;TypeScript',
#  'Dart;HTML/CSS;Python;Rust;TypeScript',
#  'Bash/Shell (all shells);Groovy;HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript',
#  'Assembly;C;C++;HTML/CSS;JavaScript;Lua;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript',
#  'Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#  'C++;Dart;Java;Lua;Python;SQL;Swift',
#  'Groovy;HTML/CSS;Java;JavaScript;Scala;SQL;TypeScript',
#  'Bash/Shell (all shells);Delphi;HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript',
#  'JavaScript;PHP;Swift;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;MicroPython;Visual Basic (.Net)',
#  'Java;JavaScript;PowerShell;Python',
#  'Assembly;C;C#;C++;Go;HTML/CSS;Java;JavaScript;MATLAB;PHP;Python;Ruby;SQL;TypeScript',
#  'Assembly;C;C#;C++;Crystal;HTML/CSS;JavaScript;Lua;MicroPython;PowerShell;Python;SQL;TypeScript;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C#;JavaScript;PowerShell;Python;SQL',
#  'Bash/Shell (all shells);Elixir;HTML/CSS;JavaScript;Python',
#  'C#;JavaScript;Python;TypeScript',
#  'Bash/Shell (all shells);JavaScript;Ruby;Rust;TypeScript',
#  'Java;PowerShell',
#  'C++;GDScript;Java;Lua;Python;Scala;TypeScript',
#  'C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;PowerShell;Python;SQL;TypeScript',
#  'C#;C++;GDScript;Groovy;Haskell;Java;JavaScript;Python;R;SQL;VBA',
#  'Go;HTML/CSS;JavaScript;PHP;SQL',
#  'Delphi;Go;Ruby',
#  'C#;C++;Kotlin;Lua;MicroPython;PowerShell;Python;Ruby;SQL;Zephyr',
#  'C#;C++;HTML/CSS;JavaScript;PowerShell;Ruby;SQL;TypeScript',
#  'C;C++;Go;Nim;Perl;PHP;Python;Rust;SQL',
#  'Bash/Shell (all shells);Go',
#  'Bash/Shell (all shells);Go;Lua;Python;SQL',
#  'C#;Dart;Python',
#  'C#;HTML/CSS;JavaScript;Python;SQL',
#  'Bash/Shell (all shells);C;C#;C++;Java;JavaScript;Objective-C;Swift',
#  'GDScript;HTML/CSS;JavaScript',
#  'Bash/Shell (all shells);C;Go;MicroPython;Python',
#  'Assembly;Bash/Shell (all shells);C;C++;Fortran;Java;JavaScript;Lua;Objective-C;Perl;PHP;Python',
#  'Bash/Shell (all shells);C;C++;Fortran;Java;OCaml;Perl;PHP;PowerShell;Python;Ruby;SQL',
#  'Ada;Apex;Assembly;Bash/Shell (all shells);C;C#;C++;Go;Groovy;Haskell;HTML/CSS;Java;JavaScript;Kotlin;Lisp;Lua;PowerShell;Python;R;Ruby;Rust;SQL;TypeScript',
#  'C#;JavaScript;Kotlin;Python;TypeScript',
#  'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Ruby;Scala;SQL',
#  'Assembly;C#;C++;JavaScript;Python;SQL;VBA;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C;C++;Go;Objective-C;PowerShell',
#  'Bash/Shell (all shells);C;C++;Dart;HTML/CSS;Java;JavaScript;Kotlin;Python;SQL',
#  'C;C#;C++;Julia;Python',
#  'Assembly;C;C#;F#;Haskell;Python;SQL',
#  'Bash/Shell (all shells);C;Go;HTML/CSS;JavaScript;OCaml;Rust;SQL;TypeScript',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript',
#  'C++;Delphi;Java;Lisp;MATLAB;Python;R;Swift;VBA',
#  'Bash/Shell (all shells);HTML/CSS;Python;SQL',
#  'C#;Go;JavaScript;Python;SQL;TypeScript',
#  'Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;Perl;PowerShell;Python;SQL;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C++;Python',
#  'C;Go;Rust;SQL',
#  'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Lua;PHP;Python;SQL;Visual Basic (.Net)',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;PowerShell;TypeScript',
#  'C',
#  'Bash/Shell (all shells);Go;Python;Rust;SQL;TypeScript',
#  'Assembly;C;Haskell;Prolog;Python;Rust',
#  'Bash/Shell (all shells);C#;HTML/CSS;JavaScript;Python;Ruby;Swift;TypeScript',
#  'Bash/Shell (all shells);JavaScript;Python;SQL',
#  'Groovy;JavaScript;SQL',
#  'Bash/Shell (all shells);JavaScript;Python;Scala;TypeScript',
#  'Bash/Shell (all shells);C#;PowerShell;SQL;TypeScript',
#  'Java;JavaScript;Rust',
#  'Bash/Shell (all shells);GDScript;HTML/CSS;Java;JavaScript;Kotlin;Lua;Python;TypeScript',
#  'Assembly;Bash/Shell (all shells);C;C#;C++;Dart;Go;Haskell;HTML/CSS;Java;JavaScript;Kotlin;Lua;Nim;Perl;PHP;Python;Ruby;Rust;SQL;Swift;TypeScript;Zig',
#  'Ruby;Scala;SQL',
#  ...]

# %%
df = remove_semicolon(df)
df.head()
# Out:
#    YearsCodePro                DevType  \
# 2            27   developer experience
# 3             0  developer, full-stack
# 4             0  developer, full-stack
# 5             0                student
# 6             7    academic researcher
#
#                               LanguageHaveWorkedWith  \
# 2                                                 C#
# 3  C,C++,HTML/CSS,Java,JavaScript,PHP,PowerShell,...
# 4            C++,HTML/CSS,JavaScript,Lua,Python,Rust
# 5  Bash/Shell (all shells),HTML/CSS,Java,JavaScri...
# 6                                                  R
#
#             DatabaseHaveWorkedWith                   PlatformHaveWorkedWith  \
# 2       Firebase Realtime Database                             Google Cloud
# 3  MongoDB,MySQL,PostgreSQL,SQLite  Amazon Web Services (AWS),Fly.io,Heroku
# 4                PostgreSQL,SQLite                                      NaN
# 5                  Cloud Firestore                               Cloudflare
# 6                              NaN                                      NaN
#
#                    WebframeHaveWorkedWith   EmbeddedHaveWorkedWith  \
# 2                            ASP.NET CORE              Rasberry Pi
# 3  jQuery,Next.js,Node.js,React,WordPress              Rasberry Pi
# 4                                     NaN  CMake,Cargo,Rasberry Pi
# 5                                 Node.js              Rasberry Pi
# 6                                     NaN                      NaN
#
#                             MiscTechHaveWorkedWith  \
# 2  .NET (5+) ,.NET Framework (1.0 - 4.8),.NET MAUI
# 3                     NumPy,Pandas,Ruff,TensorFlow
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
#
#         ToolsTechHaveWorkedWith       NEWCollabToolsHaveWorkedWith  \
# 2                       MSBuild                      Visual Studio
# 3                Docker,npm,Pip                                NaN
# 4                  APT,Make,npm                                Vim
# 5  Docker,Homebrew,npm,Pip,pnpm  Nano,Vim,Visual Studio Code,Xcode
# 6                           NaN                            RStudio
#
#          OpSysPersonal use OpSysProfessional use  \
# 2                  Windows               Windows
# 3                      NaN                   NaN
# 4  Other (please specify):                   NaN
# 5         iOS,MacOS,Ubuntu                   NaN
# 6                    MacOS                 MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 2                                                NaN
# 3                                                NaN
# 4  GitHub Discussions,Markdown File,Obsidian,Stac...
# 5                                      Markdown File
# 6                                                NaN
#
#                   OfficeStackSyncHaveWorkedWith  \
# 2  Google Chat,Google Meet,Microsoft Teams,Zoom
# 3                                           NaN
# 4                              Discord,Whatsapp
# 5                                       Discord
# 6                      Microsoft Teams,Whatsapp
#
#              AISearchDevHaveWorkedWith  WorkExp
# 2                                  NaN      0.0
# 3                                  NaN      0.0
# 4                                  NaN      0.0
# 5  ChatGPT,GitHub Copilot,OpenAI Codex      0.0
# 6                                  NaN      0.0

# %%
df.shape
# Out:
# (55803, 16)

# %%
df.fillna('0', inplace=True)
df.head()
# Out:
#    YearsCodePro                DevType  \
# 2            27   developer experience
# 3             0  developer, full-stack
# 4             0  developer, full-stack
# 5             0                student
# 6             7    academic researcher
#
#                               LanguageHaveWorkedWith  \
# 2                                                 C#
# 3  C,C++,HTML/CSS,Java,JavaScript,PHP,PowerShell,...
# 4            C++,HTML/CSS,JavaScript,Lua,Python,Rust
# 5  Bash/Shell (all shells),HTML/CSS,Java,JavaScri...
# 6                                                  R
#
#             DatabaseHaveWorkedWith                   PlatformHaveWorkedWith  \
# 2       Firebase Realtime Database                             Google Cloud
# 3  MongoDB,MySQL,PostgreSQL,SQLite  Amazon Web Services (AWS),Fly.io,Heroku
# 4                PostgreSQL,SQLite                                        0
# 5                  Cloud Firestore                               Cloudflare
# 6                                0                                        0
#
#                    WebframeHaveWorkedWith   EmbeddedHaveWorkedWith  \
# 2                            ASP.NET CORE              Rasberry Pi
# 3  jQuery,Next.js,Node.js,React,WordPress              Rasberry Pi
# 4                                       0  CMake,Cargo,Rasberry Pi
# 5                                 Node.js              Rasberry Pi
# 6                                       0                        0
#
#                             MiscTechHaveWorkedWith  \
# 2  .NET (5+) ,.NET Framework (1.0 - 4.8),.NET MAUI
# 3                     NumPy,Pandas,Ruff,TensorFlow
# 4                                                0
# 5                                                0
# 6                                                0
#
#         ToolsTechHaveWorkedWith       NEWCollabToolsHaveWorkedWith  \
# 2                       MSBuild                      Visual Studio
# 3                Docker,npm,Pip                                  0
# 4                  APT,Make,npm                                Vim
# 5  Docker,Homebrew,npm,Pip,pnpm  Nano,Vim,Visual Studio Code,Xcode
# 6                             0                            RStudio
#
#          OpSysPersonal use OpSysProfessional use  \
# 2                  Windows               Windows
# 3                        0                     0
# 4  Other (please specify):                     0
# 5         iOS,MacOS,Ubuntu                     0
# 6                    MacOS                 MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 2                                                  0
# 3                                                  0
# 4  GitHub Discussions,Markdown File,Obsidian,Stac...
# 5                                      Markdown File
# 6                                                  0
#
#                   OfficeStackSyncHaveWorkedWith  \
# 2  Google Chat,Google Meet,Microsoft Teams,Zoom
# 3                                             0
# 4                              Discord,Whatsapp
# 5                                       Discord
# 6                      Microsoft Teams,Whatsapp
#
#              AISearchDevHaveWorkedWith  WorkExp
# 2                                    0      0.0
# 3                                    0      0.0
# 4                                    0      0.0
# 5  ChatGPT,GitHub Copilot,OpenAI Codex      0.0
# 6                                    0      0.0

# %%
df['WorkExp'].dtype
# Out:
# dtype('float64')

# %%
for col, dtype in zip(df.columns, df.dtypes):
    print(f'{col}: {dtype}')
# Out:
# YearsCodePro: int64
# DevType: string
# LanguageHaveWorkedWith: object
# DatabaseHaveWorkedWith: object
# PlatformHaveWorkedWith: object
# WebframeHaveWorkedWith: object
# EmbeddedHaveWorkedWith: object
# MiscTechHaveWorkedWith: object
# ToolsTechHaveWorkedWith: object
# NEWCollabToolsHaveWorkedWith: object
# OpSysPersonal use: object
# OpSysProfessional use: object
# OfficeStackAsyncHaveWorkedWith: object
# OfficeStackSyncHaveWorkedWith: object
# AISearchDevHaveWorkedWith: object
# WorkExp: float64

# %%
df.to_pickle(Export_Path)
